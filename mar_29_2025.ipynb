# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

# %%
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
data.replace('?', np.nan, inplace=True)

# %%
na_rows = pd.isna(data['age'])
question_mark_rows = data[na_rows]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
data['sex'] = data['sex'].replace({"male": 1, "female": 0})
data['sex'] = data['sex'].astype("int64")
# Out:
# /var/folders/6l/0ln54yv53l35x35zsrv0syb40000gn/T/ipykernel_3004/1106382083.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['sex'] = data['sex'].replace({"male": 1, "female": 0})

# %%
def show_corr(data_to_show):
  corr_matrix = data.corr(numeric_only=True)

  # Set up the plot
  plt.figure(figsize=(10, 8))
  sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

  plt.title("Correlation Heatmap")
  plt.show()

# %%
# Compute correlation
show_corr(data)

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
show_corr(data)

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex', 'pclass','age','relatives','fare']], data['survived'], test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = nb_model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7033492822966507

# %%
from keras.models import Sequential
from keras.layers import Dense

nn_model = Sequential()

# %%
from keras.layers import Input

nn_model.add(Input(shape=(5,)))
nn_model.add(Dense(5, kernel_initializer='uniform', activation='relu'))
nn_model.add(Dense(5, kernel_initializer='uniform', activation='relu'))
nn_model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# %%
nn_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 5)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 5)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 66 (264.00 B)
#  Trainable params: 66 (264.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
nn_model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
nn_model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.5644 - loss: 0.6925
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - accuracy: 0.5799 - loss: 0.6907
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.5792 - loss: 0.6873
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.5772 - loss: 0.6800
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.5966 - loss: 0.6644
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.5834 - loss: 0.6465
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.5953 - loss: 0.6191
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.6322 - loss: 0.5890
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.7577 - loss: 0.5728
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.7916 - loss: 0.5537
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.7914 - loss: 0.5276
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - accuracy: 0.7920 - loss: 0.5329
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.8001 - loss: 0.5101
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.7917 - loss: 0.4988
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.7829 - loss: 0.5078
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.7848 - loss: 0.4954
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.8113 - loss: 0.4702
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.8037 - loss: 0.4682
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.7893 - loss: 0.4805
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.7938 - loss: 0.4636
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.8313 - loss: 0.4302
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.7821 - loss: 0.4900
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.7980 - loss: 0.4482
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.8011 - loss: 0.4589
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.8025 - loss: 0.4502
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.7936 - loss: 0.4576
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - accuracy: 0.7723 - loss: 0.4662
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.7882 - loss: 0.4505
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.8169 - loss: 0.4302
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - accuracy: 0.8084 - loss: 0.4318
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.7955 - loss: 0.4562
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.7818 - loss: 0.4582
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7930 - loss: 0.4464
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - accuracy: 0.7756 - loss: 0.4664
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.7957 - loss: 0.4307
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.8189 - loss: 0.4210
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.8005 - loss: 0.4389
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.7834 - loss: 0.4490
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.7975 - loss: 0.4101
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.7924 - loss: 0.4472
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - accuracy: 0.7853 - loss: 0.4393
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.7828 - loss: 0.4544
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.7874 - loss: 0.4190
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7937 - loss: 0.4475
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - accuracy: 0.7945 - loss: 0.4451
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.7963 - loss: 0.4310
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.7920 - loss: 0.4311
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7944 - loss: 0.4241
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.7970 - loss: 0.4478
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8085 - loss: 0.4232

# %%
y_pred = np.rint(nn_model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x326efa320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 0.7368421052631579

# %%
# Column names as in training
columns = ['sex', 'pclass', 'age', 'relatives', 'fare']

# New passenger input
new_passenger = pd.DataFrame([[0, 1, 35, 1, 80.0]], columns=columns)

# Scale properly (no warning)
new_scaled = sc.transform(new_passenger)

# Predict as before
nb_pred = nb_model.predict(new_scaled)[0]

# Predict using Neural Network
nn_prob = nn_model.predict(new_scaled)[0][0]
nn_pred = 1 if nn_prob >= 0.5 else 0

# Show results
print("🧠 Neural Network Prediction:", "✅ Survived" if nn_pred == 1 else "❌ Not Survived", f"(prob: {nn_prob:.2f})")
print("🪶 GaussianNB Prediction:", "✅ Survived" if nb_pred == 1 else "❌ Not Survived")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 🧠 Neural Network Prediction: ✅ Survived (prob: 0.95)
# 🪶 GaussianNB Prediction: ✅ Survived
